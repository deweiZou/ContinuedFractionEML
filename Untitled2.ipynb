# %%
from sage.plot.line import Line
from sage.plot.point import Point
var('x y')
e=sqrt(1-x^2)
f=line([(-1/2, sqrt(3)/2),(-1/2,3)])
g=line([(1/2,sqrt(3)/2),(1/2,3)])
t=region_plot(y>sqrt(1-x^2),(x,-1/2, 1/2),(y,-2,3), incol='red', bordercol='gray')
px= RR.random_element(-3,3)
py= RR.random_element(0.1,1)
P=point((px,py))
show(plot(e)+g+f+P, aspect_ratio=1)

CheckY = True
CheckX = True
Count=""

while CheckY:
    while CheckX:
        if px>0.5:
            px=px-1
            show(point((px,py))+plot(e)+g+f, aspect_ratio=1)
            Count=Count+'T^-1'
        elif px<-0.5:
            px=px+1
            show(point((px,py))+plot(e)+g+f, aspect_ratio=1)
            Count=Count+'T'
        else:
            CheckX= False

    if py<sqrt(1-px^2):
        px2=px
        py2=py
        
        CheckX=True
        
        px=-(px/(px2^2+py2^2))
        py=(py/(px2^2+py2^2))
        
        show(point((px,py))+plot(e)+g+f, aspect_ratio=1)
    else:
        CheckY=False
show(Count)
# Out:
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# Graphics object consisting of 4 graphics primitives
# 'TT'
